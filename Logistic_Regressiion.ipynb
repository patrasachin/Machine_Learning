# %% [markdown]
# <a href="https://colab.research.google.com/github/patrasachin/Machine_Learning/blob/main/Logistic_Regressiion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
#Dataset
url="https://raw.githubusercontent.com/apratim777/apratim777/refs/heads/master/insurance_data.csv"
df=pd.read_csv(url)
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color="red")

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
x=df.iloc[:,0:1].values
y=df.iloc[:,1].values
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.score(x,y)
# Out:
# 0.5364021643885125

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color="red")
plt.plot(x,reg.predict(x),color='blue')

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg=LogisticRegression()

# %%
x=df.iloc[:,0:1].values
y=df.iloc[:,1].values
reg.fit(x,y)
# Out:
# LogisticRegression()

# %%
reg.score(x,y)
# Out:
# 0.8888888888888888

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color="red")
plt.plot(x,reg.predict(x),color='blue')
